# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Missing values

# %%
## handling missing values in categorical features
features_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtype=='O']
for feature in features_nan:
    print('{} :{}% missing values'.format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# Alley :0.9377% missing values
# MasVnrType :0.0055% missing values
# BsmtQual :0.0253% missing values
# BsmtCond :0.0253% missing values
# BsmtExposure :0.026% missing values
# BsmtFinType1 :0.0253% missing values
# BsmtFinType2 :0.026% missing values
# FireplaceQu :0.4726% missing values
# GarageType :0.0555% missing values
# GarageFinish :0.0555% missing values
# GarageQual :0.0555% missing values
# GarageCond :0.0555% missing values
# PoolQC :0.9952% missing values
# Fence :0.8075% missing values
# MiscFeature :0.963% missing values

# %%
#replacing null values with a  new label
def replace_cat_feature(df,features_nan):
    data=df.copy()
    data[features_nan]=data[features_nan].fillna("Missing")
    return data

df=replace_cat_feature(df,features_nan)

df[features_nan].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... PoolArea   PoolQC    Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 1         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 2         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 3         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
# 4         Lvl    AllPub  ...        0  Missing  Missing     Missing       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
##handling missing values in numerical variables
numerical_nan=[feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtypes!='O']

for feature in  numerical_nan:
    print("{}: {}% missing values".format(feature,np.round(df[feature].isnull().mean(),4)))
# Out:
# LotFrontage: 0.1774% missing values
# MasVnrArea: 0.0055% missing values
# GarageYrBlt: 0.0555% missing values

# %%
##replacing the missing values
#since there are outliers as seen in the exploratory data analysis will use median
for feature in numerical_nan:
    median_value=df[feature].median()
    
    df[feature+'nan']=np.where(df[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace =True)
    
#check if there is any null values
df[numerical_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
df.head(50)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave  Missing      Reg
# 1    2          20       RL         80.0     9600   Pave  Missing      Reg
# 2    3          60       RL         68.0    11250   Pave  Missing      IR1
# 3    4          70       RL         60.0     9550   Pave  Missing      IR1
# 4    5          60       RL         84.0    14260   Pave  Missing      IR1
# 5    6          50       RL         85.0    14115   Pave  Missing      IR1
# 6    7          20       RL         75.0    10084   Pave  Missing      Reg
# 7    8          60       RL         69.0    10382   Pave  Missing      IR1
# 8    9          50       RM         51.0     6120   Pave  Missing      Reg
# 9   10         190       RL         50.0     7420   Pave  Missing      Reg
# 10  11          20       RL         70.0    11200   Pave  Missing      Reg
# ...

# %%
##handing date time variables
#converting then to years
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    df[feature]=df['YrSold']-df[feature]

# %%
#this shows the number of years subtracted from the YrSold
df[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %%
#from the EDA i found out that the numerical variables were skewed 
#should convert them to log normal distribution 
num_features=['LotFrontage','LotArea','1stFlrSF','GrLivArea']

for feature in num_features:
    df[feature]=np.log(df[feature])

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0   1          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1   2          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2   3          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3   4          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4   5          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
##handling rare categoriacl feature
#removing categorical features with less than 1% of the total observations
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
##finding % of each category with respect to the whole dataset
for feature in categorical_features:
    temp=df.groupby(feature)['SalePrice'].count()/len(df)
    temp_df=temp[temp>0.01].index
    df[feature]=np.where(df[feature].isin(temp_df),df[feature],'RareVar')

# %%
df.head(50)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0    1          60       RL     1.428968  2.201872   Pave  Missing      Reg
# 1    2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2    3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3    4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4    5          60       RL     1.488584  2.258133   Pave  Missing      IR1
# 5    6          50       RL     1.491251  2.257064   Pave  Missing      IR1
# 6    7          20       RL     1.462674  2.221235   Pave  Missing      Reg
# 7    8          60       RL     1.443172  2.224389   Pave  Missing      IR1
# 8    9          50       RM     1.369104  2.165541   Pave  Missing      Reg
# 9   10         190       RL     1.364055  2.187391   Pave  Missing      Reg
# 10  11          20       RL     1.446565  2.232556   Pave  Missing      Reg
# ...

# %%
for feature in categorical_features:
    labels_ordered=df.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %% [markdown]
# ## Feature scaling

# %%
feature_scale=[feature for feature in df.columns if feature not in ['Id','SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(df[feature_scale])
# Out:
# array([[0.23529412, 0.75      , 0.49689213, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.57331546, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.51381745, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.50263957, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.51381745, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.54995643, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([df[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(df[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0   1     208500    0.235294      0.75     0.496892  0.431124     1.0    1.0
# 1   2     181500    0.000000      0.75     0.573315  0.457169     1.0    1.0
# 2   3     223500    0.235294      0.75     0.513817  0.489044     1.0    1.0
# 3   4     140000    0.294118      0.75     0.466412  0.456111     1.0    1.0
# 4   5     250000    0.235294      0.75     0.590747  0.535696     1.0    1.0
#
#    LotShape  LandContour  ...  Fence  MiscFeature  MiscVal    MoSold  YrSold  \
# 0  0.000000     0.333333  ...    1.0          1.0      0.0  0.090909    0.50
# 1  0.000000     0.333333  ...    1.0          1.0      0.0  0.363636    0.25
# 2  0.333333     0.333333  ...    1.0          1.0      0.0  0.727273    0.50
# 3  0.333333     0.333333  ...    1.0          1.0      0.0  0.090909    0.00
# 4  0.333333     0.333333  ...    1.0          1.0      0.0  1.000000    0.50
#
# ...

# %%
data.to_csv('X_train.csv',index = True)
